# %% [markdown]
# # Organic Chemistry Reaction Map
# Upload or keep `organic.html` in the same directory, then run the cell below to render the interactive map.

# %%
from IPython.display import HTML, display

html_path = 'organic.html'
with open(html_path, 'r', encoding='utf-8') as f:
    display(HTML(f.read()))
